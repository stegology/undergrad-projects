# %%
def reverse_complement(dna_string):
    complement = str.maketrans('ATCG', 'TAGC')
    return dna_string[::-1].translate(complement)

dna_string = "..."
reverse_comp = reverse_complement(dna_string)
print(reverse_comp)
# Out:
# ...
